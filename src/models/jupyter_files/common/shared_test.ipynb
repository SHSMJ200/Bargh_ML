# %%
import sys, os
current_dir = os.getcwd()
project_root = current_dir[:current_dir.find("src") - 1]
sys.path.insert(0, project_root)
import pandas as pd

# %%
csv_semi_processed_path = os.path.join(project_root, "data", "interim", f"weather.csv")
df1 = pd.read_csv(csv_semi_processed_path, encoding='utf-8')

# %%
csv_semi_processed_path = os.path.join(project_root, "data", "interim", f"weather_old.csv")
df2 = pd.read_csv(csv_semi_processed_path, encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 csv_semi_processed_path = os.path.join(project_root, "data", "interim", f"weather_old.csv")
# ----> 2 df2 = pd.read_csv(csv_semi_processed_path, encoding='utf-8')
#
# ...

# %%
df1.head(10)
# Out:
#    unitid        date  time  temperature_2m  relative_humidity_2m  \
# 0     917  2021-03-23     1       11.046000                  40.0
# 1     917  2021-03-23     2       10.746000                  40.0
# 2     917  2021-03-23     3       11.396000                  41.0
# 3     917  2021-03-23     4       13.695999                  31.0
# 4     917  2021-03-23     5       15.296000                  27.0
# 5     917  2021-03-23     6       17.296000                  25.0
# 6     917  2021-03-23     7       19.095999                  24.0
# 7     917  2021-03-23     8       21.196000                  23.0
# 8     917  2021-03-23     9       24.246000                  21.0
# 9     917  2021-03-23    10       25.696000                  20.0
#
#    dew_point_2m  apparent_temperature  precipitation  rain  snowfall  \
# 0     -2.051930              8.177171            0.0   0.0       0.0
# 1     -2.321814              8.073168            0.0   0.0       0.0
# ...

# %%
df2.head(10)
# Out:
#    unitid        date  time  temperature_2m  relative_humidity_2m  \
# 0     917  2021-03-23     1       11.046000                  40.0
# 1     917  2021-03-23     2       10.746000                  40.0
# 2     917  2021-03-23     3       11.396000                  41.0
# 3     917  2021-03-23     4       13.695999                  31.0
# 4     917  2021-03-23     5       15.296000                  27.0
# 5     917  2021-03-23     6       17.296000                  25.0
# 6     917  2021-03-23     7       19.095999                  24.0
# 7     917  2021-03-23     8       21.196000                  23.0
# 8     917  2021-03-23     9       24.246000                  21.0
# 9     917  2021-03-23    10       25.696000                  20.0
#
#    dew_point_2m  apparent_temperature  precipitation  rain  snowfall  \
# 0     -2.051930              8.177171            0.0   0.0       0.0
# 1     -2.321814              8.073168            0.0   0.0       0.0
# ...

# %%
df1['temperature_2m'].values == df2['temperature_2m'].values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df1['temperature_2m'].values == df2['temperature_2m'].values
#
# ValueError: operands could not be broadcast together with shapes (455156,) (455195,)

# %%
df3 = df1.merge(df2, how="inner", on=["date","unitid","time"])

# %%
len(df3)
# Out:
# 455143

# %%
len(df1)
# Out:
# 455156

# %%
len(df2)
# Out:
# 455195

# %%
df3[['temperature_2m_x','temperature_2m_y']]
# Out:
#         temperature_2m_x  temperature_2m_y
# 0              10.746000         11.046000
# 1              11.396000         10.746000
# 2              13.695999         11.396000
# 3              15.296000         13.695999
# 4              17.296000         15.296000
# ...                  ...               ...
# 455138         18.531000         19.681000
# 455139         16.831000         18.531000
# 455140         17.531000         16.831000
# 455141         16.980999         17.531000
# 455142         16.531000         16.980999
#
# [455143 rows x 2 columns]

# %%
df1.columns
# Out:
# Index(['unitid', 'date', 'time', 'temperature_2m', 'relative_humidity_2m',
#        'dew_point_2m', 'apparent_temperature', 'precipitation', 'rain',
#        'snowfall', 'surface_pressure', 'evapotranspiration', 'wind_speed_10m',
#        'wind_direction_10m'],
#       dtype='object')
